# %%
#Import math Library
import math

#find the exponential of the specified value
math.exp(10)
# Out:
# 22026.465794806718

# %%
x = [5,6,11,7]
z = 0
for i in x:
  print("x ", i)
  print("exp(x) ", math.exp(i))
  z = z + math.exp(i)
print("sum of exp: ", z)
# Out:
# x  5
# exp(x)  148.4131591025766
# x  6
# exp(x)  403.4287934927351
# x  11
# exp(x)  59874.14171519782
# x  7
# exp(x)  1096.6331584284585
# sum of exp:  61522.61682622159

# %%
for i in x:
  print("x ", i)
  print("softmax output ", math.exp(i)/z)
# Out:
# x  5
# softmax output  0.0024123349551562205
# x  6
# softmax output  0.00655740627275772
# x  11
# softmax output  0.9732053804590254
# x  7
# softmax output  0.017824878313060667
