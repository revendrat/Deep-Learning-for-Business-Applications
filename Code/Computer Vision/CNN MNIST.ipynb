# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Prepare & load the data from MNIST

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build Model

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 12s 6ms/step - loss: 0.3624 - accuracy: 0.8918 - val_loss: 0.0826 - val_accuracy: 0.9782
# Epoch 2/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.1128 - accuracy: 0.9647 - val_loss: 0.0582 - val_accuracy: 0.9840
# Epoch 3/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0846 - accuracy: 0.9741 - val_loss: 0.0472 - val_accuracy: 0.9865
# Epoch 4/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0691 - accuracy: 0.9795 - val_loss: 0.0449 - val_accuracy: 0.9887
# Epoch 5/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0614 - accuracy: 0.9815 - val_loss: 0.0376 - val_accuracy: 0.9898
# Epoch 6/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0554 - accuracy: 0.9828 - val_loss: 0.0369 - val_accuracy: 0.9895
# Epoch 7/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0510 - accuracy: 0.9837 - val_loss: 0.0338 - val_accuracy: 0.9910
# Epoch 8/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0467 - accuracy: 0.9845 - val_loss: 0.0365 - val_accuracy: 0.9888
# Epoch 9/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0443 - accuracy: 0.9862 - val_loss: 0.0319 - val_accuracy: 0.9910
# Epoch 10/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0420 - accuracy: 0.9867 - val_loss: 0.0318 - val_accuracy: 0.9920
# Epoch 11/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0385 - accuracy: 0.9875 - val_loss: 0.0310 - val_accuracy: 0.9917
# Epoch 12/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0360 - accuracy: 0.9882 - val_loss: 0.0314 - val_accuracy: 0.9913
# Epoch 13/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0362 - accuracy: 0.9880 - val_loss: 0.0297 - val_accuracy: 0.9920
# Epoch 14/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0343 - accuracy: 0.9888 - val_loss: 0.0298 - val_accuracy: 0.9912
# Epoch 15/15
# 422/422 [==============================] - 2s 5ms/step - loss: 0.0325 - accuracy: 0.9895 - val_loss: 0.0278 - val_accuracy: 0.9927

# %%
## Evaluate the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.022448599338531494
# Test accuracy: 0.9922000169754028

# %% [markdown]
# Reference: https://keras.io/examples/vision/mnist_convnet/
